# %% [markdown]
# # import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',50)
pd.set_option('display.max_row',100)
# %matplotlib inline

# %% [markdown]
# # import dataset

# %%
df = pd.read_csv('https://github.com/khala1391/DSL_Dataset/raw/main/project_2_Cars_Dataset.csv')
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# # Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
# df_object = df.select_dtypes(include='object')
# df_object

# %%
df_number = df.select_dtypes(include='number').copy()
df_number.columns
# Out:
# Index(['EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df[['EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
       'Weight', 'Wheelbase', 'Length']].hist(figsize =(8,8))
# Out:
# array([[<Axes: title={'center': 'EngineSize'}>,
#         <Axes: title={'center': 'Cylinders'}>,
#         <Axes: title={'center': 'Horsepower'}>],
#        [<Axes: title={'center': 'MPG_City'}>,
#         <Axes: title={'center': 'MPG_Highway'}>,
#         <Axes: title={'center': 'Weight'}>],
#        [<Axes: title={'center': 'Wheelbase'}>,
#         <Axes: title={'center': 'Length'}>, <Axes: >]], dtype=object)

# %%
df[['Model','Type']].value_counts()
# Out:
# Model                  Type
# C320 4dr               Sedan     2
# C240 4dr               Sedan     2
# G35 4dr                Sedan     2
# 3.5 RL 4dr             Sedan     1
# Passat W8 4MOTION 4dr  Sedan     1
#                                 ..
# Eclipse GTS 2dr        Sports    1
# Echo 4dr               Sedan     1
# Echo 2dr manual        Sedan     1
# Echo 2dr auto          Sedan     1
# xB                     Wagon     1
# Name: count, Length: 425, dtype: int64

# %%
df.query('Model == "C320 4dr"| Model == "C240 4dr"| Model == "G35 4dr"')
# Out:
#               Make     Model   Type  Origin DriveTrain      MSRP   Invoice  \
# 183       Infiniti   G35 4dr  Sedan    Asia       Rear  $28,495   $26,157
# 185       Infiniti   G35 4dr  Sedan    Asia        All  $32,445   $29,783
# 259  Mercedes-Benz  C240 4dr  Sedan  Europe       Rear  $32,280   $30,071
# 260  Mercedes-Benz  C240 4dr  Sedan  Europe        All  $33,480   $31,187
# 262  Mercedes-Benz  C320 4dr  Sedan  Europe       Rear  $37,630   $35,046
# 263  Mercedes-Benz  C320 4dr  Sedan  Europe        All  $38,830   $36,162
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 183         3.5        6.0       260.0      18.0         26.0  3336.0
# 185         3.5        6.0       260.0      18.0         26.0  3677.0
# 259         2.6        6.0       168.0      20.0         25.0  3360.0
# 260         2.6        6.0       168.0      19.0         25.0  3360.0
# 262         3.2        6.0       215.0      20.0         26.0  3450.0
# ...

# %% [markdown]
# ### finding:
# 1) 'MSRP', 'Invoice' need to convert to numberic
#    - remove nan and symbol
#    - convert dtype

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.isna().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df[df.isna().all(axis=1)]  # return row with NaN (whole row)
# Out:
#     Make Model Type Origin DriveTrain MSRP Invoice  EngineSize  Cylinders  \
# 30   NaN   NaN  NaN    NaN        NaN  NaN     NaN         NaN        NaN
# 39   NaN   NaN  NaN    NaN        NaN  NaN     NaN         NaN        NaN
# 161  NaN   NaN  NaN    NaN        NaN  NaN     NaN         NaN        NaN
# 173  NaN   NaN  NaN    NaN        NaN  NaN     NaN         NaN        NaN
#
#      Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 30          NaN       NaN          NaN     NaN        NaN     NaN
# 39          NaN       NaN          NaN     NaN        NaN     NaN
# 161         NaN       NaN          NaN     NaN        NaN     NaN
# 173         NaN       NaN          NaN     NaN        NaN     NaN

# %%
df[df.isna().any(axis=1)]  # return row with NaN (any)
# Out:
#       Make               Model    Type Origin DriveTrain      MSRP   Invoice  \
# 30     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 39     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 161    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 173    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 251  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700   $23,794
# 252  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200   $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 30          NaN        NaN         NaN       NaN          NaN     NaN
# 39          NaN        NaN         NaN       NaN          NaN     NaN
# 161         NaN        NaN         NaN       NaN          NaN     NaN
# 173         NaN        NaN         NaN       NaN          NaN     NaN
# 251         1.3        NaN       197.0      18.0         25.0  3053.0
# ...

# %%
df.shape
# Out:
# (432, 15)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Dropna

# %%
df = df.dropna(how="all").reset_index(drop=True).copy()
df.shape
# Out:
# (428, 15)

# %%
df[df.isna().any(axis=1)]  # return row with NaN (any)
# Out:
#       Make               Model    Type Origin DriveTrain      MSRP   Invoice  \
# 247  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700   $23,794
# 248  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200   $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 247         1.3        NaN       197.0      18.0         25.0  3053.0
# 248         1.3        NaN       238.0      18.0         24.0  3029.0
#
#      Wheelbase  Length
# 247      106.0   174.0
# 248      106.0   174.0

# %%
df.isna().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %% [markdown]
# ## Dtype

# %%
df[['MSRP', 'Invoice']] = df[['MSRP', 'Invoice']].replace({r'\$': '', ',': ''}, regex=True).astype('int32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    int32
#  6   Invoice      428 non-null    int32
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), int32(2), object(5)
# memory usage: 46.9+ KB

# %%
df['Cylinders'].describe()
# Out:
# count    426.000000
# mean       5.807512
# std        1.558443
# min        3.000000
# 25%        4.000000
# 50%        6.000000
# 75%        6.000000
# max       12.000000
# Name: Cylinders, dtype: float64

# %%
df['Cylinders'].plot(kind='kde');

# %% [markdown]
# ## Impute Missing Value

# %%
df[df.isna().any(axis=1)]  # return row with NaN (any)
# Out:
#       Make               Model    Type Origin DriveTrain   MSRP  Invoice  \
# 247  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  25700    23794
# 248  Mazda     RX-8 4dr manual  Sports   Asia       Rear  27200    25179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 247         1.3        NaN       197.0      18.0         25.0  3053.0
# 248         1.3        NaN       238.0      18.0         24.0  3029.0
#
#      Wheelbase  Length
# 247      106.0   174.0
# 248      106.0   174.0

# %%
df[(df.Make =='Mazda') & (df.Model.str.contains('RX-8', case=False))]

# df[(df.brand == 'AUDI')&(df['2000cc'] >=7)]
# df.manufacturer.str.contains('toyoTa|nissan|Honda', case=False)
# Out:
#       Make               Model    Type Origin DriveTrain   MSRP  Invoice  \
# 247  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  25700    23794
# 248  Mazda     RX-8 4dr manual  Sports   Asia       Rear  27200    25179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 247         1.3        NaN       197.0      18.0         25.0  3053.0
# 248         1.3        NaN       238.0      18.0         24.0  3029.0
#
#      Wheelbase  Length
# 247      106.0   174.0
# 248      106.0   174.0

# %%
df.plot.scatter (x='EngineSize', y ='Cylinders')
# Out:
# <Axes: xlabel='EngineSize', ylabel='Cylinders'>

# %% [markdown]
# ### finding:
#      EngineSize Seem to match with no. Cylinder
#      in this case, it should be assume to be '4'
# ### next action:
#      replace NaN to 4
#      explore some abnormal points i.e. Cylinder to low/high

# %%
# df[['EngineSize','Cylinders']].plot(kind='kde')

# %%
df[(df.Cylinders < 4) | (df.Cylinders > 8)]
# Out:
#               Make                         Model    Type  Origin DriveTrain  \
# 114          Dodge  Viper SRT-10 convertible 2dr  Sports     USA       Rear
# 118           Ford             Excursion 6.8 XLT     SUV     USA        All
# 150          Honda    Insight 2dr (gas/electric)  Hybrid    Asia      Front
# 262  Mercedes-Benz                     CL600 2dr   Sedan  Europe       Rear
# 271  Mercedes-Benz         SL600 convertible 2dr  Sports  Europe       Rear
# 412     Volkswagen               Phaeton W12 4dr   Sedan  Europe      Front
#
#        MSRP  Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 114   81795    74451         8.3       10.0       500.0      12.0
# 118   41475    36494         6.8       10.0       310.0      10.0
# 150   19110    17911         2.0        3.0        73.0      60.0
# 262  128420   119600         5.5       12.0       493.0      13.0
# 271  126670   117854         5.5       12.0       493.0      13.0
# ...

# %%
df_Honda = df[(df.Make =='Honda') & (df.Model.str.contains('2dr', case=False))]
df_Honda
# Out:
#       Make                       Model    Type Origin DriveTrain   MSRP  \
# 150  Honda  Insight 2dr (gas/electric)  Hybrid   Asia      Front  19110
# 154  Honda                Civic DX 2dr   Sedan   Asia      Front  13270
# 155  Honda                Civic HX 2dr   Sedan   Asia      Front  14170
# 157  Honda               Accord LX 2dr   Sedan   Asia      Front  19860
# 158  Honda               Accord EX 2dr   Sedan   Asia      Front  22260
# 160  Honda          Civic Si 2dr hatch   Sedan   Asia      Front  19490
# 162  Honda            Accord EX V6 2dr   Sedan   Asia      Front  26960
# 165  Honda       S2000 convertible 2dr  Sports   Asia       Rear  33260
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 150    17911         2.0        3.0        73.0      60.0         66.0
# 154    12175         1.7        4.0       115.0      32.0         38.0
# 155    12996         1.7        4.0       117.0      36.0         44.0
# ...

# %%
# df_Honda.plot.scatter (x='Cylinders', y ='Horsepower')

# %%
# df.columns

# %%
sns.pairplot(df, vars= ['EngineSize', 'Cylinders', 'Horsepower'],
                 hue ='Type', corner= True)
plt.show()

# %%
# %%timeit
# df[(df.Make =='Mazda') & (df.Model.str.contains('RX-8', case=False))].fillna(value=4)

# %%
# %%timeit
df['Cylinders'] = df['Cylinders'].fillna(value=4)
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Type, Origin, DriveTrain, MSRP, Invoice, EngineSize, Cylinders, Horsepower, MPG_City, MPG_Highway, Weight, Wheelbase, Length]
# Index: []

# %%
df.isna().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.reset_index(drop=True)
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        All  36945    33337
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820    21761
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990    24647
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195    30299
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755    39014
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565    38203
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565    40083
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210    42573
# 426  Volvo                      V40  Wagon  Europe      Front  26135    24641
# 427  Volvo                     XC70  Wagon  Europe        All  35145    33112
#
# ...

# %% [markdown]
# # Data Preparation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    int32
#  6   Invoice      428 non-null    int32
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    428 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), int32(2), object(5)
# memory usage: 46.9+ KB

# %%
# df_number = df.select_dtypes(include='number')
# df_number

# %%
df.corr(numeric_only=True)
# Out:
#                  MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# MSRP         1.000000  0.999132    0.571753   0.649308    0.826945 -0.475020
# Invoice      0.999132  1.000000    0.564498   0.644753    0.823746 -0.470442
# EngineSize   0.571753  0.564498    1.000000   0.908186    0.787435 -0.709471
# Cylinders    0.649308  0.644753    0.908186   1.000000    0.807523 -0.679872
# Horsepower   0.826945  0.823746    0.787435   0.807523    1.000000 -0.676699
# MPG_City    -0.475020 -0.470442   -0.709471  -0.679872   -0.676699  1.000000
# MPG_Highway -0.439622 -0.434585   -0.717302  -0.671488   -0.647195  0.941021
# Weight       0.448426  0.442332    0.807867   0.742849    0.630796 -0.737966
# Wheelbase    0.152000  0.148328    0.636517   0.546337    0.387398 -0.507284
# Length       0.172037  0.166586    0.637448   0.549785    0.381554 -0.501526
#
#              MPG_Highway    Weight  Wheelbase    Length
# MSRP           -0.439622  0.448426   0.152000  0.172037
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
sns.pairplot(df, vars= ['Horsepower', 'MPG_Highway','Weight','Wheelbase', 'Length'],\
                 hue='Type',corner=True)
plt.show()

# %%
df[['Horsepower', 'MPG_Highway','Weight', 'Wheelbase', 'Length']].corr(numeric_only=True)
# Out:
#              Horsepower  MPG_Highway    Weight  Wheelbase    Length
# Horsepower     1.000000    -0.647195  0.630796   0.387398  0.381554
# MPG_Highway   -0.647195     1.000000 -0.790989  -0.524661 -0.466092
# Weight         0.630796    -0.790989  1.000000   0.760703  0.690021
# Wheelbase      0.387398    -0.524661  0.760703   1.000000  0.889195
# Length         0.381554    -0.466092  0.690021   0.889195  1.000000

# %% [markdown]
# ### finding:
# #### correlation
#     - Horsepower with Weight = 0.630796
#     - MPG_Highway with Weight = -0.790989
#                 with Horsepower = -0.647195

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        All  36945    33337
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820    21761
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990    24647
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195    30299
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755    39014
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565    38203
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565    40083
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210    42573
# 426  Volvo                      V40  Wagon  Europe      Front  26135    24641
# 427  Volvo                     XC70  Wagon  Europe        All  35145    33112
#
# ...

# %% [markdown]
# ## Descriptive#1 bar plot

# %%
print(df['Make'].value_counts())
df['Make'].value_counts().to_frame().reset_index().nlargest(10,'count').plot(kind='bar',x='Make', ylabel ='count')
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64
# <Axes: xlabel='Make', ylabel='count'>

# %%
print(df['Type'].value_counts())
df['Type'].value_counts().to_frame().reset_index().plot(kind='bar',x='Type', ylabel ='count',figsize = (6,4))
# Out:
# Type
# Sedan     262
# SUV        60
# Sports     49
# Wagon      30
# Truck      24
# Hybrid      3
# Name: count, dtype: int64
# <Axes: xlabel='Type', ylabel='count'>

# %%
print(df['DriveTrain'].value_counts())
df['DriveTrain'].value_counts().to_frame().reset_index().plot(kind='bar',x='DriveTrain', ylabel ='count',figsize = (6,4))
# Out:
# DriveTrain
# Front    226
# Rear     110
# All       92
# Name: count, dtype: int64
# <Axes: xlabel='DriveTrain', ylabel='count'>

# %% [markdown]
# ## Descriptive#2 boxplot

# %%
df.boxplot(column=['MPG_Highway'], by=['Make'], vert=False, grid=False, figsize=(10, 8));

# %%
df.boxplot(column=['MPG_Highway'], by=['Type'], vert=False, grid=False, figsize=(6, 4));

# %%
df.boxplot(column=['MPG_Highway'], by=['DriveTrain'], vert=False, grid=False, figsize=(6, 4));

# %%
df.boxplot(column=['EngineSize'], by=['Make'], vert=True, grid=False, figsize=(10, 4), rot=90);

# %%
df.boxplot(column=['EngineSize'], by=['Type'], vert=True, grid=False, figsize=(6, 4), rot=90);

# %%
df.boxplot(column=['EngineSize'], by=['DriveTrain'], vert=True, grid=False, figsize=(6, 4),rot=90);

# %% [markdown]
# ## Descriptive#3 Top

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain   MSRP  Invoice  EngineSize  \
# 0  Acura             MDX    SUV   Asia        All  36945    33337         3.5
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820    21761         2.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990    24647         2.4
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195    30299         3.2
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755    39014         3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0        6.0       265.0      17.0         23.0  4451.0      106.0   189.0
# 1        4.0       200.0      24.0         31.0  2778.0      101.0   172.0
# 2        4.0       200.0      22.0         29.0  3230.0      105.0   183.0
# 3        6.0       270.0      20.0         28.0  3575.0      108.0   186.0
# 4        6.0       225.0      18.0         24.0  3880.0      115.0   197.0

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df['Make'].value_counts().to_frame().reset_index().nlargest(3,'count')
# Out:
#             Make  count
# 0         Toyota     28
# 1      Chevrolet     27
# 2  Mercedes-Benz     26

# %% [markdown]
# ## Drop column | Change Dtype - df_top

# %%
df_top = df.query('Make == ["Toyota", "Chevrolet","Mercedes-Benz"]').drop(columns=['Model','Origin','MSRP', 'Invoice','Wheelbase', 'Length'])
df_top
# Out:
#               Make    Type DriveTrain  EngineSize  Cylinders  Horsepower  \
# 63       Chevrolet     SUV      Front         5.3        8.0       295.0
# 64       Chevrolet     SUV        All         5.3        8.0       295.0
# 65       Chevrolet     SUV      Front         4.2        6.0       275.0
# 66       Chevrolet     SUV      Front         2.5        6.0       165.0
# 67       Chevrolet   Sedan      Front         1.6        4.0       103.0
# 68       Chevrolet   Sedan      Front         1.6        4.0       103.0
# 69       Chevrolet   Sedan      Front         2.2        4.0       140.0
# 70       Chevrolet   Sedan      Front         2.2        4.0       140.0
# 71       Chevrolet   Sedan      Front         2.2        4.0       140.0
# 72       Chevrolet   Sedan      Front         3.4        6.0       180.0
# 73       Chevrolet   Sedan      Front         2.2        4.0       145.0
# 74       Chevrolet   Sedan      Front         3.5        6.0       200.0
# ...

# %%
df_top = df_top.astype({'Make':'category',\
                        # 'Model': 'category',\
                        'Type':'category',\
                        # 'Origin':'category',\
                        'DriveTrain':'category',\
                        # 'MSRP':'int16',\
                        'EngineSize':'float16',\
                        'Cylinders':'int16',\
                        'Horsepower':'int16',\
                        'MPG_Highway':'int16',\
                        'Weight':'int16'
              })
df_top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 63 to 400
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         81 non-null     category
#  1   Type         81 non-null     category
#  2   DriveTrain   81 non-null     category
#  3   EngineSize   81 non-null     float16
#  4   Cylinders    81 non-null     int16
#  5   Horsepower   81 non-null     int16
#  6   MPG_City     81 non-null     float64
#  7   MPG_Highway  81 non-null     int16
#  8   Weight       81 non-null     int16
# dtypes: category(3), float16(1), float64(1), int16(4)
# memory usage: 2.8 KB

# %%
sns.pairplot(df_top, vars= ['Horsepower', 'MPG_Highway','Weight'],\
                 hue='DriveTrain',corner=True)
plt.show()

# %%
df['Type'].value_counts().to_frame().reset_index().nlargest(3,'count')
# Out:
#      Type  count
# 0   Sedan    262
# 1     SUV     60
# 2  Sports     49

# %%
df_top = df.query('Type == ["Sedan", "SUV","Sports"]')

# %%
sns.pairplot(df_top, vars= ['Horsepower', 'MPG_Highway','Weight'],\
                 hue='DriveTrain',corner=True)
plt.show()

# %%
df['DriveTrain'].value_counts().to_frame().reset_index().nlargest(1,'count')
# Out:
#   DriveTrain  count
# 0      Front    226

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        All  36945    33337
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820    21761
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990    24647
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195    30299
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755    39014
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565    38203
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565    40083
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210    42573
# 426  Volvo                      V40  Wagon  Europe      Front  26135    24641
# 427  Volvo                     XC70  Wagon  Europe        All  35145    33112
#
# ...

# %%
df_top = df.query('DriveTrain == ["Front"]')

# %%
sns.pairplot(df_top, vars= ['Horsepower', 'MPG_Highway','Weight'],\
                 hue='Type',corner=True)
plt.show()

# %%
df_top = df.query('Type == ["Wagon"]')

# %%
sns.pairplot(df_top, vars= ['Horsepower', 'MPG_Highway','Weight'],\
                 hue='DriveTrain',corner=True)
plt.show()

# %% [markdown]
# ## Drop column | Change Dtype - df

# %%
df = df.drop(columns=['Model','Origin','Invoice','MPG_City','Wheelbase','Length'])
df
# Out:
#       Make   Type DriveTrain   MSRP  EngineSize  Cylinders  Horsepower  \
# 0    Acura    SUV        All  36945         3.5        6.0       265.0
# 1    Acura  Sedan      Front  23820         2.0        4.0       200.0
# 2    Acura  Sedan      Front  26990         2.4        4.0       200.0
# 3    Acura  Sedan      Front  33195         3.2        6.0       270.0
# 4    Acura  Sedan      Front  43755         3.5        6.0       225.0
# ..     ...    ...        ...    ...         ...        ...         ...
# 423  Volvo  Sedan      Front  40565         2.4        5.0       197.0
# 424  Volvo  Sedan      Front  42565         2.3        5.0       242.0
# 425  Volvo  Sedan      Front  45210         2.9        6.0       268.0
# 426  Volvo  Wagon      Front  26135         1.9        4.0       170.0
# 427  Volvo  Wagon        All  35145         2.5        5.0       208.0
#
#      MPG_Highway  Weight
# 0           23.0  4451.0
# 1           31.0  2778.0
# 2           29.0  3230.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Type         428 non-null    object
#  2   DriveTrain   428 non-null    object
#  3   MSRP         428 non-null    int32
#  4   EngineSize   428 non-null    float64
#  5   Cylinders    428 non-null    float64
#  6   Horsepower   428 non-null    float64
#  7   MPG_Highway  428 non-null    float64
#  8   Weight       428 non-null    float64
# dtypes: float64(5), int32(1), object(3)
# memory usage: 28.6+ KB

# %%
df.columns
# Out:
# Index(['Make', 'Type', 'DriveTrain', 'MSRP', 'EngineSize', 'Cylinders',
#        'Horsepower', 'MPG_Highway', 'Weight'],
#       dtype='object')

# %%
df.astype({'Cylinders':'int',\
           'Horsepower':'int',\
           'MPG_Highway':'int',\
           'Weight':'int'
          })
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Type         428 non-null    object
#  2   DriveTrain   428 non-null    object
#  3   MSRP         428 non-null    int32
#  4   EngineSize   428 non-null    float64
#  5   Cylinders    428 non-null    float64
#  6   Horsepower   428 non-null    float64
#  7   MPG_Highway  428 non-null    float64
#  8   Weight       428 non-null    float64
# dtypes: float64(5), int32(1), object(3)
# memory usage: 28.6+ KB

# %%
df = df.astype({'Make':'category',\
                'Type':'category',\
                'DriveTrain':'category',\
                'MSRP':'int32',\
                # 'EngineSize':'float8',\
                'Cylinders':'int16',\
                'Horsepower':'int16',\
                'MPG_Highway':'int16',\
                'Weight':'int16'
              })
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    category
#  1   Type         428 non-null    category
#  2   DriveTrain   428 non-null    category
#  3   MSRP         428 non-null    int32
#  4   EngineSize   428 non-null    float64
#  5   Cylinders    428 non-null    int16
#  6   Horsepower   428 non-null    int16
#  7   MPG_Highway  428 non-null    int16
#  8   Weight       428 non-null    int16
# dtypes: category(3), float64(1), int16(4), int32(1)
# memory usage: 11.4 KB

# %%
df
# Out:
#       Make   Type DriveTrain   MSRP  EngineSize  Cylinders  Horsepower  \
# 0    Acura    SUV        All  36945         3.5          6         265
# 1    Acura  Sedan      Front  23820         2.0          4         200
# 2    Acura  Sedan      Front  26990         2.4          4         200
# 3    Acura  Sedan      Front  33195         3.2          6         270
# 4    Acura  Sedan      Front  43755         3.5          6         225
# ..     ...    ...        ...    ...         ...        ...         ...
# 423  Volvo  Sedan      Front  40565         2.4          5         197
# 424  Volvo  Sedan      Front  42565         2.3          5         242
# 425  Volvo  Sedan      Front  45210         2.9          6         268
# 426  Volvo  Wagon      Front  26135         1.9          4         170
# 427  Volvo  Wagon        All  35145         2.5          5         208
#
#      MPG_Highway  Weight
# 0             23    4451
# 1             31    2778
# 2             29    3230
# ...

# %%
df_top.head(5)
# Out:
#           Make                 Model   Type  Origin DriveTrain   MSRP  \
# 24        Audi  A6 3.0 Avant Quattro  Wagon  Europe        All  40840
# 25        Audi      S4 Avant Quattro  Wagon  Europe        All  49090
# 45         BMW           325xi Sport  Wagon  Europe        All  32845
# 89   Chevrolet        Malibu Maxx LS  Wagon     USA      Front  22225
# 104   Chrysler              Pacifica  Wagon     USA       Rear  31230
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 24     37060         3.0        6.0       220.0      18.0         25.0
# 25     44446         4.2        8.0       340.0      15.0         21.0
# 45     30110         2.5        6.0       184.0      19.0         26.0
# 89     20394         3.5        6.0       200.0      22.0         30.0
# 104    28725         3.5        6.0       250.0      17.0         23.0
#
#      Weight  Wheelbase  Length
# 24   4035.0      109.0   192.0
# 25   3936.0      104.0   179.0
# ...

# %%
df.head()
# Out:
#     Make   Type DriveTrain   MSRP  EngineSize  Cylinders  Horsepower  \
# 0  Acura    SUV        All  36945         3.5          6         265
# 1  Acura  Sedan      Front  23820         2.0          4         200
# 2  Acura  Sedan      Front  26990         2.4          4         200
# 3  Acura  Sedan      Front  33195         3.2          6         270
# 4  Acura  Sedan      Front  43755         3.5          6         225
#
#    MPG_Highway  Weight
# 0           23    4451
# 1           31    2778
# 2           29    3230
# 3           28    3575
# 4           24    3880

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ## Importing the dataset

# %%
df.columns
# Out:
# Index(['Make', 'Type', 'DriveTrain', 'MSRP', 'EngineSize', 'Cylinders',
#        'Horsepower', 'MPG_Highway', 'Weight'],
#       dtype='object')

# %%
# df_category_in =['Make', 'Type', 'DriveTrain']
# df_numeric_in = ['EngineSize', 'Cylinders','Horsepower','Weight']
# df_target_out =['MPG_Highway']
# df_selected_cols = df_category_in + df_numeric_in +df_target_out

# %%
X =df[['DriveTrain','EngineSize', 'Cylinders','Horsepower','Weight']]
y =df[['MPG_Highway']]

# %%
# X = X.to_numpy()

# %%
# y = y.to_numpy()

# %%
# X = df[df_numeric_in]
# y = df[df_target_out]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Encoding the Independent Variable

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')

# %%
# X = np.array(ct.fit_transform(X))

# %%
X = ct.fit_transform(X)

# %%
print(X)
# Out:
# [[1.000e+00 0.000e+00 0.000e+00 ... 6.000e+00 2.650e+02 4.451e+03]
#  [0.000e+00 1.000e+00 0.000e+00 ... 4.000e+00 2.000e+02 2.778e+03]
#  [0.000e+00 1.000e+00 0.000e+00 ... 4.000e+00 2.000e+02 3.230e+03]
#  ...
#  [0.000e+00 1.000e+00 0.000e+00 ... 6.000e+00 2.680e+02 3.653e+03]
#  [0.000e+00 1.000e+00 0.000e+00 ... 4.000e+00 1.700e+02 2.822e+03]
#  [1.000e+00 0.000e+00 0.000e+00 ... 5.000e+00 2.080e+02 3.823e+03]]

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
type(X_test)
# Out:
# numpy.ndarray

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y_test)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, 3:] = sc.fit_transform(X_train[:, 3:])
X_test[:, 3:] = sc.transform(X_test[:, 3:])

# %%
print(X_train)
# Out:
# [[ 1.          0.          0.         ... -1.16452262 -0.5729893
#    0.05634097]
#  [ 0.          0.          1.         ... -1.16452262 -1.19388619
#   -1.1828136 ]
#  [ 0.          1.          0.         ...  0.10215111 -0.43501222
#    0.15848387]
#  ...
#  [ 0.          0.          1.         ... -1.16452262 -1.02831369
#   -1.11695831]
#  [ 0.          0.          1.         ...  1.36882483  0.31006405
#    1.05895411]
#  [ 0.          0.          1.         ...  0.10215111  0.11689613
#   -0.14660083]]

# %%
print(X_test)
# Out:
# [[ 0.          1.          0.         -1.08964097 -1.16452262 -1.08350452
#   -1.27151664]
#  [ 0.          1.          0.          0.2540219   0.10215111 -0.22804659
#   -0.35760654]
#  [ 0.          1.          0.         -1.08964097 -1.16452262 -1.19388619
#   -1.3024283 ]
#  [ 0.          1.          0.         -1.26879602 -1.16452262 -1.19388619
#   -1.4502667 ]
#  [ 0.          0.          1.          1.41852972  1.36882483  0.94475865
#    1.2995275 ]
#  [ 0.          0.          1.         -0.19386573  0.10215111  0.04790759
#    0.09128459]
#  [ 0.          1.          0.         -1.26879602 -1.16452262 -1.19388619
#   -1.21238128]
#  [ 0.          1.          0.          0.2540219   0.10215111  0.11689613
#    0.40174523]
#  [ 0.          0.          1.         -0.01471068  0.10215111  0.0617053
#    0.51732798]
#  [ 0.          1.          0.          1.23937467  1.36882483  0.21348009
#    1.90700892]
# ...

# %%
print(y_train)
# Out:
#      MPG_Highway
# 85            23
# 329           36
# 81            26
# 349           35
# 256           25
# ..           ...
# 255           25
# 72            32
# 397           27
# 235           25
# 37            30
#
# [341 rows x 1 columns]

# %%
print(y_test)
# Out:
#      MPG_Highway
# 172           34
# 78            32
# 122           33
# 379           40
# 146           20
# 224           25
# 400           36
# 4             24
# 275           27
# 119           19
# 376           24
# 5             24
# 47            26
# 365           22
# 164           25
# 283           23
# 201           21
# 17            24
# 207           32
# 342           30
# 272           29
# 295           28
# 157           34
# 233           24
# 411           22
# 426           29
# 296           28
# 228           24
# 339           29
# 383           39
# 29            29
# 244           25
# 62            17
# 65            21
# 395           33
# 415           25
# 354           28
# 356           28
# 314           18
# 232           26
# 360           27
# 332           24
# 304           26
# 307           28
# 187           20
# 285           26
# 326           26
# 90            29
# 245           28
# 251           14
# 161           30
# ...

# %% [markdown]
# ## Training the Multiple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred = np.ravel(y_pred)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
y_pred.shape
# Out:
# (86,)

# %%
dc=pd.concat([y_test.reset_index(), pd.Series(y_pred, name='Predicted').round(decimals=2)], axis='columns')
dc
# Out:
#     index  MPG_Highway  Predicted
# 0     172           34      33.29
# 1      78           32      29.15
# 2     122           33      33.52
# 3     379           40      34.03
# 4     146           20      20.58
# 5     224           25      25.78
# 6     400           36      33.28
# 7       4           24      26.34
# 8     275           27      24.36
# 9     119           19      21.28
# 10    376           24      23.52
# 11      5           24      26.28
# 12     47           26      26.38
# 13    365           22      28.01
# 14    164           25      24.02
# 15    283           23      21.86
# 16    201           21      27.08
# 17     17           24      21.91
# 18    207           32      34.68
# 19    342           30      27.59
# 20    272           29      28.82
# 21    295           28      29.42
# 22    157           34      31.31
# 23    233           24      24.20
# 24    411           22      18.90
# 25    426           29      32.01
# ...

# %%
y_test['MPG_Highway'].max()
# Out:
# 40

# %% [markdown]
# ## Evaluating the Model Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7722720424074343

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
print('RMSE',sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MAE 1.999133473252464
# MSE 6.142281181767576
# RMSE 2.4783626009459505

# %% [markdown]
# ## Improve Model Performance

# %%
ax = plt.subplot()

h = ax.plot(range(0, 50), range(0, 50))

x = y_test
y = y_pred
QQ = ax.scatter(x,y)

# %%
print(dc)
# Out:
#     index  MPG_Highway  Predicted
# 0     172           34      33.29
# 1      78           32      29.15
# 2     122           33      33.52
# 3     379           40      34.03
# 4     146           20      20.58
# 5     224           25      25.78
# 6     400           36      33.28
# 7       4           24      26.34
# 8     275           27      24.36
# 9     119           19      21.28
# 10    376           24      23.52
# 11      5           24      26.28
# 12     47           26      26.38
# 13    365           22      28.01
# 14    164           25      24.02
# 15    283           23      21.86
# 16    201           21      27.08
# 17     17           24      21.91
# 18    207           32      34.68
# 19    342           30      27.59
# 20    272           29      28.82
# 21    295           28      29.42
# 22    157           34      31.31
# 23    233           24      24.20
# 24    411           22      18.90
# 25    426           29      32.01
# ...

# %%
df.iloc[373:374,]
# Out:
#        Make    Type DriveTrain   MSRP  EngineSize  Cylinders  Horsepower  \
# 373  Toyota  Hybrid      Front  20510         1.5          4         110
#
#      MPG_Highway  Weight
# 373           51    2890

# %%
print(df.shape)
# Out:
# (427, 9)

# %%
# df = df.drop(373)
# print(df.shape)
# Out:
# (427, 9)

# %% [markdown]
# rerun 'Multiple Linear Regression'

# %% [markdown]
# before: 0.6779056725658247
# after: 0.7722720424074343
