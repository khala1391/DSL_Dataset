# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/khala1391/DSL_Dataset/main/data/project_5_London_Housing_Dataset.csv'

# %%
df = pd.read_csv(url,index_col='date', parse_dates=True, date_format="%Y/%m/%d")
df.head(5)
# Out:
#                     area  average_price       code  houses_sold  no_of_crimes
# date
# 1/1/1995  city of london          91449  E09000001         17.0           NaN
# 2/1/1995  city of london          82203  E09000001          7.0           NaN
# 3/1/1995  city of london          79121  E09000001         14.0           NaN
# 4/1/1995  city of london          77101  E09000001          7.0           NaN
# 5/1/1995  city of london          84409  E09000001         10.0           NaN

# %%
df = df.astype({'average_price': 'float64'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13549 entries, 1/1/1995 to 1/1/2020
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area           13549 non-null  object
#  1   average_price  13549 non-null  float64
#  2   code           13549 non-null  object
#  3   houses_sold    13455 non-null  float64
#  4   no_of_crimes   7439 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 1.1+ MB

# %%
df_object = df.select_dtypes(include='object').copy()
df_number = df.select_dtypes(include='number').copy()

# %%
df.no_of_crimes.plot(kind='line');

# %%
df.hist(bins=20);

# %%
df.describe()
# Out:
#        average_price    houses_sold  no_of_crimes
# count   1.354900e+04   13455.000000   7439.000000
# mean    2.635197e+05    3893.994129   2158.352063
# std     1.876175e+05   12114.402476    902.087742
# min     4.072200e+04       2.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000
# 50%     2.229190e+05     371.000000   2132.000000
# 75%     3.368430e+05    3146.000000   2582.000000
# max     1.463378e+06  132163.000000   7461.000000

# %%
df.boxplot(column=['average_price','houses_sold'], 
           by='area',vert=False, grid=False,sharex=False, sharey= True,
           figsize=(12,10));

# %%
df.boxplot(column=['no_of_crimes'], by='area',vert=False, grid=False, figsize=(12,10));

# %%
df.columns

# %%
df.nlargest(10, columns = 'no_of_crimes')
# Out:
#                   area  average_price       code  houses_sold  no_of_crimes
# date
# 12/1/2019  westminster       968404.0  E09000033          NaN        7461.0
# 4/1/2019   westminster       992834.0  E09000033        155.0        7227.0
# 3/1/2019   westminster       960161.0  E09000033        185.0        7215.0
# 10/1/2019  westminster       927864.0  E09000033        168.0        7208.0
# 5/1/2002   westminster       331670.0  E09000033        573.0        7076.0
# 8/1/2019   westminster       914870.0  E09000033        156.0        7069.0
# 7/1/2002   westminster       353874.0  E09000033        665.0        7012.0
# 8/1/2001   westminster       309873.0  E09000033        566.0        7002.0
# 7/1/2019   westminster       957897.0  E09000033        168.0        6991.0
# 6/1/2019   westminster       997393.0  E09000033        155.0        6931.0

# %%
df.isna().sum()
# Out:
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# df.info()
# Out:
#                      area  average_price       code  houses_sold  no_of_crimes
# date
# 1/1/1995   city of london        91449.0  E09000001         17.0           NaN
# 2/1/1995   city of london        82203.0  E09000001          7.0           NaN
# 3/1/1995   city of london        79121.0  E09000001         14.0           NaN
# 4/1/1995   city of london        77101.0  E09000001          7.0           NaN
# 5/1/1995   city of london        84409.0  E09000001         10.0           NaN
# ...                   ...            ...        ...          ...           ...
# 9/1/2019          england       249942.0  E92000001      64605.0           NaN
# 10/1/2019         england       249376.0  E92000001      68677.0           NaN
# 11/1/2019         england       248515.0  E92000001      67814.0           NaN
# 12/1/2019         england       250410.0  E92000001          NaN           NaN
# 1/1/2020          england       247355.0  E92000001          NaN           NaN
#
# ...
