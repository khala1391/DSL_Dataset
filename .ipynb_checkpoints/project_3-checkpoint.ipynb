# %% [markdown]
# ## Import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns',50)

# %%
# import ydata_profiling as pp

# %%
from ydata_profiling import ProfileReport

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('https://github.com/khala1391/DSL/raw/main/project_3_Police_Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65535 non-null  object
#  1   stop_time           65535 non-null  object
#  2   country_name        0 non-null      float64
#  3   driver_gender       61474 non-null  object
#  4   driver_age_raw      61481 non-null  float64
#  5   driver_age          61228 non-null  float64
#  6   driver_race         61475 non-null  object
#  7   violation_raw       61475 non-null  object
#  8   violation           61475 non-null  object
#  9   search_conducted    65535 non-null  bool
#  10  search_type         2479 non-null   object
#  11  stop_outcome        61475 non-null  object
#  12  is_arrested         61475 non-null  object
#  13  stop_duration       61475 non-null  object
#  14  drugs_related_stop  65535 non-null  bool
# ...

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-22 05:08:09.859757&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
df_object = df.select_dtypes(include='object').copy()
df_object
# Out:
#        stop_date stop_time driver_gender driver_race  \
# 0       1/2/2005      1:55             M       White
# 1      1/18/2005      8:15             M       White
# 2      1/23/2005     23:15             M       White
# 3      2/20/2005     17:15             M       White
# 4      3/14/2005     10:00             F       White
# ...          ...       ...           ...         ...
# 65530  12/6/2012     17:54             F       White
# 65531  12/6/2012     22:22             M       White
# 65532  12/6/2012     23:20             M       Black
# 65533  12/7/2012      0:23           NaN         NaN
# 65534  12/7/2012      0:30             F       White
#
#                         violation_raw  violation search_type   stop_outcome  \
# 0                            Speeding   Speeding         NaN       Citation
# 1                            Speeding   Speeding         NaN       Citation
# 2                            Speeding   Speeding         NaN       Citation
# ...

# %%
# df.select_dtypes('number')

# %%
df_number = df.select_dtypes(include='number').copy()
df_number

# %%
df_number.columns
# Out:
# Index(['country_name', 'driver_age_raw', 'driver_age'], dtype='object')

# %%
df[['country_name', 'driver_age_raw', 'driver_age']].hist()
# Out:
# array([[<Axes: title={'center': 'country_name'}>,
#         <Axes: title={'center': 'driver_age_raw'}>],
#        [<Axes: title={'center': 'driver_age'}>, <Axes: >]], dtype=object)

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %%
df['driver_gender'].value_counts()
# Out:
# driver_gender
# M    45164
# F    16310
# Name: count, dtype: int64

# %%
df['driver_race'].value_counts()
# Out:
# driver_race
# White       45747
# Black        8267
# Hispanic     5611
# Asian        1639
# Other         211
# Name: count, dtype: int64

# %%
df['violation_raw'].value_counts()
# Out:
# violation_raw
# Speeding                            37204
# Other Traffic Violation             11926
# Equipment/Inspection Violation       6516
# Special Detail/Directed Patrol       2383
# Registration Violation               2243
# Call for Service                      793
# Violation of City/Town Ordinance      170
# Motorist Assist/Courtesy              138
# APB                                    51
# Suspicious Person                      38
# Warrant                                10
# Seatbelt Violation                      3
# Name: count, dtype: int64

# %%
df['violation'].value_counts()
# Out:
# violation
# Speeding               37204
# Moving violation       11926
# Equipment               6516
# Other                   3583
# Registration/plates     2243
# Seat belt                  3
# Name: count, dtype: int64

# %%
df['search_conducted'].value_counts()
# Out:
# search_conducted
# False    63056
# True      2479
# Name: count, dtype: int64

# %%
df['search_type'].value_counts()
# Out:
# search_type
# Incident to Arrest                                          1074
# Probable Cause                                               579
# Inventory                                                    173
# Reasonable Suspicion                                         149
# Protective Frisk                                             126
# Incident to Arrest,Inventory                                 104
# Incident to Arrest,Probable Cause                             79
# Probable Cause,Reasonable Suspicion                           38
# Incident to Arrest,Protective Frisk                           31
# Incident to Arrest,Inventory,Probable Cause                   26
# Probable Cause,Protective Frisk                               23
# Inventory,Probable Cause                                      14
# Inventory,Protective Frisk                                    11
# Incident to Arrest,Inventory,Protective Frisk                 11
# ...

# %%
df['stop_outcome'].value_counts()
# Out:
# stop_outcome
# Citation            56564
# Arrest Driver        2009
# Warning              1889
# N/D                   423
# No Action             339
# Arrest Passenger      251
# Name: count, dtype: int64

# %%
df['is_arrested'].value_counts()
# Out:
# is_arrested
# False    59215
# True      2260
# Name: count, dtype: int64

# %%
df['stop_duration'].value_counts()
# Out:
# stop_duration
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: count, dtype: int64

# %%
df['drugs_related_stop'].value_counts()
# Out:
# drugs_related_stop
# False    65017
# True       518
# Name: count, dtype: int64

# %% [markdown]
# ## Data Exploration : Overview

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65535 non-null  object
#  1   stop_time           65535 non-null  object
#  2   country_name        0 non-null      float64
#  3   driver_gender       61474 non-null  object
#  4   driver_age_raw      61481 non-null  float64
#  5   driver_age          61228 non-null  float64
#  6   driver_race         61475 non-null  object
#  7   violation_raw       61475 non-null  object
#  8   violation           61475 non-null  object
#  9   search_conducted    65535 non-null  bool
#  10  search_type         2479 non-null   object
#  11  stop_outcome        61475 non-null  object
#  12  is_arrested         61475 non-null  object
#  13  stop_duration       61475 non-null  object
#  14  drugs_related_stop  65535 non-null  bool
# ...

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %%
df.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data type

# %%
df['stop_date'] = pd.to_datetime(df.stop_date, format='%m/%d/%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65535 non-null  datetime64[ns]
#  1   stop_time           65535 non-null  object
#  2   country_name        0 non-null      float64
#  3   driver_gender       61474 non-null  object
#  4   driver_age_raw      61481 non-null  float64
#  5   driver_age          61228 non-null  float64
#  6   driver_race         61475 non-null  object
#  7   violation_raw       61475 non-null  object
#  8   violation           61475 non-null  object
#  9   search_conducted    65535 non-null  bool
#  10  search_type         2479 non-null   object
#  11  stop_outcome        61475 non-null  object
#  12  is_arrested         61475 non-null  object
#  13  stop_duration       61475 non-null  object
#  14  drugs_related_stop  65535 non-null  bool
# ...

# %%
df['stop_time'] = pd.to_datetime(df.stop_time, format='%H:%M').dt.time

# %%
df.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0 2005-01-02  01:55:00           NaN             M          1985.0
# 1 2005-01-18  08:15:00           NaN             M          1965.0
# 2 2005-01-23  23:15:00           NaN             M          1972.0
# 3 2005-02-20  17:15:00           NaN             M          1986.0
# 4 2005-03-14  10:00:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %% [markdown]
# ### Drop unused columns

# %%
df = df.drop(columns=['country_name','driver_age_raw','violation_raw','search_type']).copy()

# %%
df = df.astype({'driver_gender':'category',\
                'driver_age': 'float16',\
                'driver_race':'category',\
                'violation':'category',\
                'search_conducted':'bool',\
                'stop_outcome':'category',\
                'is_arrested':'bool',\
                'stop_duration':'category',\
                'drugs_related_stop':'bool'
               })
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65535 non-null  datetime64[ns]
#  1   stop_time           65535 non-null  object
#  2   driver_gender       61474 non-null  category
#  3   driver_age          61228 non-null  float16
#  4   driver_race         61475 non-null  category
#  5   violation           61475 non-null  category
#  6   search_conducted    65535 non-null  bool
#  7   stop_outcome        61475 non-null  category
#  8   is_arrested         65535 non-null  bool
#  9   stop_duration       61475 non-null  category
#  10  drugs_related_stop  65535 non-null  bool
# dtypes: bool(3), category(5), datetime64[ns](1), float16(1), object(1)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#    stop_date stop_time driver_gender  driver_age driver_race violation  \
# 0 2005-01-02  01:55:00             M        20.0       White  Speeding
# 1 2005-01-18  08:15:00             M        40.0       White  Speeding
# 2 2005-01-23  23:15:00             M        33.0       White  Speeding
# 3 2005-02-20  17:15:00             M        19.0       White     Other
# 4 2005-03-14  10:00:00             F        21.0       White  Speeding
#
#    search_conducted   stop_outcome  is_arrested stop_duration  \
# 0             False       Citation        False      0-15 Min
# 1             False       Citation        False      0-15 Min
# 2             False       Citation        False      0-15 Min
# 3             False  Arrest Driver         True     16-30 Min
# 4             False       Citation        False      0-15 Min
#
#    drugs_related_stop
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False

# %%
df['driver_gender'].isna().sum()
# Out:
# 4061

# %%
df.query('driver_gender.isna() & driver_age.isna() & violation.isna()')
# Out:
#        stop_date stop_time driver_gender  driver_age driver_race violation  \
# 25    2005-09-03  16:02:00           NaN         NaN         NaN       NaN
# 29    2005-09-26  01:05:00           NaN         NaN         NaN       NaN
# 52    2005-10-01  13:09:00           NaN         NaN         NaN       NaN
# 110   2005-10-03  19:50:00           NaN         NaN         NaN       NaN
# 124   2005-10-04  11:43:00           NaN         NaN         NaN       NaN
# ...          ...       ...           ...         ...         ...       ...
# 65427 2012-12-02  03:23:00           NaN         NaN         NaN       NaN
# 65488 2012-12-05  08:35:00           NaN         NaN         NaN       NaN
# 65493 2012-12-05  13:20:00           NaN         NaN         NaN       NaN
# 65502 2012-12-05  23:57:00           NaN         NaN         NaN       NaN
# 65533 2012-12-07  00:23:00           NaN         NaN         NaN       NaN
#
#        search_conducted stop_outcome  is_arrested stop_duration  \
# ...

# %% [markdown]
# ### Drop row

# %%
print(df.shape)
df = df.drop(df.query('driver_gender.isna() & driver_age.isna() & violation.isna()').index)
print(df.shape)
# Out:
# (65535, 11)
# (61480, 11)

# %%
df_arrested = df[df['is_arrested']==True]

# %%
df_arrested.shape
# Out:
# (2265, 11)

# %%
df_arrested.head()
# Out:
#     stop_date stop_time driver_gender  driver_age driver_race  \
# 3  2005-02-20  17:15:00             M        19.0       White
# 22 2005-08-08  02:09:00             M        50.0       Black
# 24 2005-08-28  01:00:00             M        26.0       White
# 31 2005-09-28  06:20:00             M        23.0       White
# 40 2005-10-01  00:00:00             M        17.0       White
#
#            violation  search_conducted   stop_outcome  is_arrested  \
# 3              Other             False  Arrest Driver         True
# 22  Moving violation             False  Arrest Driver         True
# 24  Moving violation              True  Arrest Driver         True
# 31          Speeding             False  Arrest Driver         True
# 40         Equipment              True  Arrest Driver         True
#
#    stop_duration  drugs_related_stop
# 3      16-30 Min               False
# 22       30+ Min               False
# 24     16-30 Min               False
# ...

# %%
df.isna().sum()
# Out:
# stop_date               0
# stop_time               0
# driver_gender           6
# driver_age            252
# driver_race             5
# violation               5
# search_conducted        0
# stop_outcome            5
# is_arrested             0
# stop_duration           5
# drugs_related_stop      0
# dtype: int64

# %% [markdown]
# ## Data Exploration in detail: GroupBy

# %%
df_arrested.groupby(['driver_race','driver_gender'],observed=False)[['driver_age']].agg(['mean','min','max'])
# Out:
#                           driver_age
#                                 mean   min   max
# driver_race driver_gender
# Asian       F              34.285713  20.0  49.0
#             M              26.083334  19.0  38.0
# Black       F              30.537735  18.0  60.0
#             M              31.047945  15.0  70.0
# Hispanic    F              28.470589  16.0  48.0
#             M              30.372990  15.0  65.0
# Other       F                    NaN   NaN   NaN
#             M              33.500000  23.0  44.0
# White       F              31.645485  15.0  68.0
#             M              33.117645  16.0  79.0

# %%
df_arrested.groupby(['search_conducted','violation'],observed=False)[['is_arrested']].count()
# Out:
#                                       is_arrested
# search_conducted violation
# False            Equipment                    274
#                  Moving violation             403
#                  Other                        159
#                  Registration/plates          172
#                  Seat belt                      0
#                  Speeding                     284
# True             Equipment                    196
#                  Moving violation             307
#                  Other                         97
#                  Registration/plates          104
#                  Seat belt                      0
#                  Speeding                     264

# %%
df_arrested.groupby(['stop_outcome'],observed=False)[['is_arrested']].count().sort_values(by='is_arrested',ascending=False)
# Out:
#                   is_arrested
# stop_outcome
# Arrest Driver            2009
# Arrest Passenger          251
# Citation                    0
# N/D                         0
# No Action                   0
# Warning                     0

# %%
df_arrested.groupby(['stop_outcome','driver_gender'],observed=False)[['is_arrested']].count().sort_values(by='is_arrested',ascending=False)
# Out:
#                                 is_arrested
# stop_outcome     driver_gender
# Arrest Driver    M                     1639
#                  F                      370
# Arrest Passenger M                      157
#                  F                       94
# Citation         F                        0
#                  M                        0
# N/D              F                        0
#                  M                        0
# No Action        F                        0
#                  M                        0
# Warning          F                        0
#                  M                        0

# %%
df_arrested.groupby(['drugs_related_stop'],observed=False)[['is_arrested']].count().sort_values(by='is_arrested')
# Out:
#                     is_arrested
# drugs_related_stop
# True                        167
# False                      2098

# %%
df_arrested_bydate = df_arrested.groupby(['stop_date'],observed=False)[['is_arrested']].count().sort_values(by='is_arrested')
df_arrested_bydate = df_arrested_bydate.sort_index()

# %%
df_arrested_bydate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1443 entries, 2005-02-20 to 2012-11-30
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   is_arrested  1443 non-null   int64
# dtypes: int64(1)
# memory usage: 22.5 KB

# %%
df_arrested_bydate.hist()
# Out:
# array([[<Axes: title={'center': 'is_arrested'}>]], dtype=object)

# %%
df_arrested_bydate.plot(kind='line', figsize = (20,6));

# %%
df_arrested_bydate.loc['2012-01-01':'2012-06-30', :].plot(kind='line', figsize = (20,6));

# %%
df_arrested_bydate2 = df_arrested_bydate.reset_index().copy()
df_arrested_bydate2
# Out:
#       stop_date  is_arrested
# 0    2005-02-20            1
# 1    2005-08-08            1
# 2    2005-08-28            1
# 3    2005-09-28            1
# 4    2005-10-01            2
# ...         ...          ...
# 1438 2012-11-26            2
# 1439 2012-11-27            1
# 1440 2012-11-28            1
# 1441 2012-11-29            1
# 1442 2012-11-30            1
#
# [1443 rows x 2 columns]

# %%
df_arrested_bydate2['year']=df_arrested_bydate2['stop_date'].dt.year
df_arrested_bydate2['month']=df_arrested_bydate2['stop_date'].dt.month
df_arrested_bydate2['day']=df_arrested_bydate2['stop_date'].dt.day
df_arrested_bydate2= df_arrested_bydate2[['stop_date','year','month','day','is_arrested']]
df_arrested_bydate2
# Out:
#       stop_date  year  month  day  is_arrested
# 0    2005-02-20  2005      2   20            1
# 1    2005-08-08  2005      8    8            1
# 2    2005-08-28  2005      8   28            1
# 3    2005-09-28  2005      9   28            1
# 4    2005-10-01  2005     10    1            2
# ...         ...   ...    ...  ...          ...
# 1438 2012-11-26  2012     11   26            2
# 1439 2012-11-27  2012     11   27            1
# 1440 2012-11-28  2012     11   28            1
# 1441 2012-11-29  2012     11   29            1
# 1442 2012-11-30  2012     11   30            1
#
# [1443 rows x 5 columns]

# %%
df_arrested_bydate2.columns
# Out:
# Index(['stop_date', 'year', 'month', 'day', 'is_arrested'], dtype='object')

# %%
ax = df_arrested_bydate2.groupby(['year'],observed=False)[['is_arrested']].count().sort_values(by=['year'],ascending=True)
ax.plot();
