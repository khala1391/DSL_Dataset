# %%
import pandas as pd
print(f'pandas version: {pd.__version__}')
# Out:
# pandas version: 2.2.1

# %%
url='https://github.com/prasertcbs/basic-dataset/raw/master/mpg30.csv'
df=pd.read_csv(url)
df
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0          audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 1          audi                  a4    3.1  2008    6    auto(av)   f   18
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 3     chevrolet              malibu    3.1  1999    6    auto(l4)   f   18
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 5         dodge   dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge   dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 7         dodge         caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 8         dodge         caravan 2wd    3.8  1999    6    auto(l4)   f   15
# 9         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 10        dodge         caravan 2wd    2.4  1999    4    auto(l3)   f   18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  30 non-null     object
#  1   model         30 non-null     object
#  2   displ         30 non-null     float64
#  3   year          30 non-null     int64
#  4   cyl           30 non-null     int64
#  5   trans         30 non-null     object
#  6   drv           30 non-null     object
#  7   cty           30 non-null     int64
#  8   hwy           30 non-null     int64
#  9   fl            30 non-null     object
#  10  class         30 non-null     object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 2.7+ KB

# %%
df.memory_usage(deep=True)
# Out:
# Index            132
# manufacturer    1889
# model           2040
# displ            240
# year             240
# cyl              240
# trans           1966
# drv             1740
# cty              240
# hwy              240
# fl              1740
# class           1890
# dtype: int64

# %%
df.query('displ>3')
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 1          audi                  a4    3.1  2008    6    auto(av)   f   18
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 3     chevrolet              malibu    3.1  1999    6    auto(l4)   f   18
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 5         dodge   dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge   dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 7         dodge         caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 8         dodge         caravan 2wd    3.8  1999    6    auto(l4)   f   15
# 9         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 11         ford        explorer 4wd    4.0  1999    6  manual(m5)   4   15
# 12         ford        explorer 4wd    4.0  1999    6    auto(l5)   4   14
# ...

# %%
df.query('displ>4')
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 5         dodge   dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge   dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 9         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 13         ford             mustang    4.6  2008    8    auto(l5)   r   15
# 14         ford     f150 pickup 4wd    4.6  1999    8  manual(m5)   4   13
# 15         ford             mustang    4.6  2008    8  manual(m5)   r   15
# 19         jeep  grand cherokee 4wd    6.1  2008    8    auto(l5)   4   11
# 20   land rover         range rover    4.4  2008    8    auto(s6)   4   12
#
#     hwy fl       class
# 2    17  r         suv
# 4    20  r         suv
# 5    12  e      pickup
# 6    15  r      pickup
# ...

# %%
df.query('4<displ<6')
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 5         dodge   dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge   dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 9         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 13         ford             mustang    4.6  2008    8    auto(l5)   r   15
# 14         ford     f150 pickup 4wd    4.6  1999    8  manual(m5)   4   13
# 15         ford             mustang    4.6  2008    8  manual(m5)   r   15
# 20   land rover         range rover    4.4  2008    8    auto(s6)   4   12
#
#     hwy fl       class
# 4    20  r         suv
# 5    12  e      pickup
# 6    15  r      pickup
# 9    17  r         suv
# 13   22  r  subcompact
# 14   16  r      pickup
# 15   23  r  subcompact
# 20   18  r         suv

# %%
df.query('(4<displ<6)&(hwy<17)')
# Out:
#    manufacturer              model  displ  year  cyl       trans drv  cty  \
# 5         dodge  dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge  dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 14         ford    f150 pickup 4wd    4.6  1999    8  manual(m5)   4   13
#
#     hwy fl   class
# 5    12  e  pickup
# 6    15  r  pickup
# 14   16  r  pickup

# %%
df.query('manufacturer =="toyota"|manufacturer =="honda"')
# Out:
#    manufacturer              model  displ  year  cyl       trans drv  cty  \
# 16        honda              civic    1.6  1999    4    auto(l4)   f   24
# 17        honda              civic    1.8  2008    4  manual(m5)   f   26
# 26       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4   15
# 27       toyota        4runner 4wd    2.7  1999    4  manual(m5)   4   15
#
#     hwy fl       class
# 16   32  r  subcompact
# 17   34  r  subcompact
# 26   17  r      pickup
# 27   20  r         suv

# %%
df.query('manufacturer in ["toyota","honda"]')
# Out:
#    manufacturer              model  displ  year  cyl       trans drv  cty  \
# 16        honda              civic    1.6  1999    4    auto(l4)   f   24
# 17        honda              civic    1.8  2008    4  manual(m5)   f   26
# 26       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4   15
# 27       toyota        4runner 4wd    2.7  1999    4  manual(m5)   4   15
#
#     hwy fl       class
# 16   32  r  subcompact
# 17   34  r  subcompact
# 26   17  r      pickup
# 27   20  r         suv

# %%
df.query('manufacturer not in ["toyota","honda"]')
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0          audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 1          audi                  a4    3.1  2008    6    auto(av)   f   18
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 3     chevrolet              malibu    3.1  1999    6    auto(l4)   f   18
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 5         dodge   dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge   dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 7         dodge         caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 8         dodge         caravan 2wd    3.8  1999    6    auto(l4)   f   15
# 9         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 10        dodge         caravan 2wd    2.4  1999    4    auto(l3)   f   18
# ...

# %%
df[df.manufacturer.isin(['toyota','honda'])]
# Out:
#    manufacturer              model  displ  year  cyl       trans drv  cty  \
# 16        honda              civic    1.6  1999    4    auto(l4)   f   24
# 17        honda              civic    1.8  2008    4  manual(m5)   f   26
# 26       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4   15
# 27       toyota        4runner 4wd    2.7  1999    4  manual(m5)   4   15
#
#     hwy fl       class
# 16   32  r  subcompact
# 17   34  r  subcompact
# 26   17  r      pickup
# 27   20  r         suv

# %%
df.loc[df.manufacturer.isin(['toyota','honda'])]
# Out:
#    manufacturer              model  displ  year  cyl       trans drv  cty  \
# 16        honda              civic    1.6  1999    4    auto(l4)   f   24
# 17        honda              civic    1.8  2008    4  manual(m5)   f   26
# 26       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4   15
# 27       toyota        4runner 4wd    2.7  1999    4  manual(m5)   4   15
#
#     hwy fl       class
# 16   32  r  subcompact
# 17   34  r  subcompact
# 26   17  r      pickup
# 27   20  r         suv

# %%
df.manufacturer.isin(['toyota','honda'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28    False
# 29    False
# Name: manufacturer, dtype: bool

# %%
df[~ df.manufacturer.isin(['toyota','honda'])]
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0          audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 1          audi                  a4    3.1  2008    6    auto(av)   f   18
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 3     chevrolet              malibu    3.1  1999    6    auto(l4)   f   18
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 5         dodge   dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge   dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 7         dodge         caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 8         dodge         caravan 2wd    3.8  1999    6    auto(l4)   f   15
# 9         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 10        dodge         caravan 2wd    2.4  1999    4    auto(l3)   f   18
# ...

# %%
df.manufacturer.unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'nissan', 'pontiac', 'subaru', 'toyota',
#        'volkswagen'], dtype=object)

# %%
df.manufacturer.nunique()
# Out:
# 13

# %%
df.query('manufacturer.str.startswith("f")')
# Out:
#    manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 11         ford     explorer 4wd    4.0  1999    6  manual(m5)   4   15   19
# 12         ford     explorer 4wd    4.0  1999    6    auto(l5)   4   14   17
# 13         ford          mustang    4.6  2008    8    auto(l5)   r   15   22
# 14         ford  f150 pickup 4wd    4.6  1999    8  manual(m5)   4   13   16
# 15         ford          mustang    4.6  2008    8  manual(m5)   r   15   23
#
#    fl       class
# 11  r         suv
# 12  r         suv
# 13  r  subcompact
# 14  r      pickup
# 15  r  subcompact

# %%
df.manufacturer.str.match('[a]')
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: manufacturer, dtype: bool

# %%
df[df.manufacturer.str.match('[a]')]
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 1         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
#
#      class
# 0  compact
# 1  compact

# %%
df.manufacturer.str.match('[af]')
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: manufacturer, dtype: bool

# %%
df[df.manufacturer.str.match('[af]')]
# Out:
#    manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 0          audi       a4 quattro    2.0  2008    4  manual(m6)   4   20   28
# 1          audi               a4    3.1  2008    6    auto(av)   f   18   27
# 11         ford     explorer 4wd    4.0  1999    6  manual(m5)   4   15   19
# 12         ford     explorer 4wd    4.0  1999    6    auto(l5)   4   14   17
# 13         ford          mustang    4.6  2008    8    auto(l5)   r   15   22
# 14         ford  f150 pickup 4wd    4.6  1999    8  manual(m5)   4   13   16
# 15         ford          mustang    4.6  2008    8  manual(m5)   r   15   23
#
#    fl       class
# 0   p     compact
# 1   p     compact
# 11  r         suv
# 12  r         suv
# 13  r  subcompact
# 14  r      pickup
# 15  r  subcompact

# %%
df[df.manufacturer.str.match('[^af]')]
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 3     chevrolet              malibu    3.1  1999    6    auto(l4)   f   18
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 5         dodge   dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge   dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 7         dodge         caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 8         dodge         caravan 2wd    3.8  1999    6    auto(l4)   f   15
# 9         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 10        dodge         caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 16        honda               civic    1.6  1999    4    auto(l4)   f   24
# 17        honda               civic    1.8  2008    4  manual(m5)   f   26
# ...

# %%
df[df.manufacturer.str.match('[c-f]')]
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 3     chevrolet              malibu    3.1  1999    6    auto(l4)   f   18
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 5         dodge   dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 6         dodge   dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 7         dodge         caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 8         dodge         caravan 2wd    3.8  1999    6    auto(l4)   f   15
# 9         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 10        dodge         caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 11         ford        explorer 4wd    4.0  1999    6  manual(m5)   4   15
# 12         ford        explorer 4wd    4.0  1999    6    auto(l5)   4   14
# ...

# %%
df[df.model.str.match(r'\d')]
# Out:
#    manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 27       toyota  4runner 4wd    2.7  1999    4  manual(m5)   4   15   20  r
#
#    class
# 27   suv

# %%
df[df.model.str.match(r'a\d')]
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 1         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
#
#      class
# 0  compact
# 1  compact

# %%
df[df.model.str.match(r'\w\d')]
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0          audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 1          audi                  a4    3.1  2008    6    auto(av)   f   18
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 14         ford     f150 pickup 4wd    4.6  1999    8  manual(m5)   4   13
#
#     hwy fl    class
# 0    28  p  compact
# 1    27  p  compact
# 2    17  r      suv
# 4    20  r      suv
# 14   16  r   pickup

# %%
df[df.model.str.match(r'\w+\d')]
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0          audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 1          audi                  a4    3.1  2008    6    auto(av)   f   18
# 2     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 4     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 14         ford     f150 pickup 4wd    4.6  1999    8  manual(m5)   4   13
#
#     hwy fl    class
# 0    28  p  compact
# 1    27  p  compact
# 2    17  r      suv
# 4    20  r      suv
# 14   16  r   pickup

# %%
df[df.model.str.match(r'\d+')]
# Out:
#    manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 27       toyota  4runner 4wd    2.7  1999    4  manual(m5)   4   15   20  r
#
#    class
# 27   suv

# %%
df[df.model.str.match('.i')]
# Out:
#    manufacturer    model  displ  year  cyl       trans drv  cty  hwy fl  \
# 16        honda    civic    1.6  1999    4    auto(l4)   f   24   32  r
# 17        honda    civic    1.8  2008    4  manual(m5)   f   26   34  r
# 18      hyundai  tiburon    2.0  1999    4    auto(l4)   f   19   26  r
#
#          class
# 16  subcompact
# 17  subcompact
# 18  subcompact
