# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/prasertcbs/tutorial/master/mpg.csv')      #dataframe
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df['type']=df.trans.str[0]

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class type
# 0    compact    a
# 1    compact    m
# 2    compact    m
# 3    compact    a
# ...

# %%
df['class'].unique()
# Out:
# array(['compact', 'midsize', 'suv', '2seater', 'minivan', 'pickup',
#        'subcompact'], dtype=object)

# %%
df.fl.unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
df.fl.nunique()
# Out:
# 5

# %%
df.select_dtypes(include='number')
# Out:
#      displ  year  cyl  cty  hwy
# 0      1.8  1999    4   18   29
# 1      1.8  1999    4   21   29
# 2      2.0  2008    4   20   31
# 3      2.0  2008    4   21   30
# 4      2.8  1999    6   16   26
# ..     ...   ...  ...  ...  ...
# 229    2.0  2008    4   19   28
# 230    2.0  2008    4   21   29
# 231    2.8  1999    6   16   26
# 232    2.8  1999    6   18   26
# 233    3.6  2008    6   17   26
#
# [234 rows x 5 columns]

# %%
df.select_dtypes(include='number')
# Out:
#      displ  year  cyl  cty  hwy
# 0      1.8  1999    4   18   29
# 1      1.8  1999    4   21   29
# 2      2.0  2008    4   20   31
# 3      2.0  2008    4   21   30
# 4      2.8  1999    6   16   26
# ..     ...   ...  ...  ...  ...
# 229    2.0  2008    4   19   28
# 230    2.0  2008    4   21   29
# 231    2.8  1999    6   16   26
# 232    2.8  1999    6   18   26
# 233    3.6  2008    6   17   26
#
# [234 rows x 5 columns]

# %%
df.describe().round(2).T
# Out:
#        count     mean   std     min     25%     50%     75%     max
# displ  234.0     3.47  1.29     1.6     2.4     3.3     4.6     7.0
# year   234.0  2003.50  4.51  1999.0  1999.0  2003.5  2008.0  2008.0
# cyl    234.0     5.89  1.61     4.0     4.0     6.0     8.0     8.0
# cty    234.0    16.86  4.26     9.0    14.0    17.0    19.0    35.0
# hwy    234.0    23.44  5.95    12.0    18.0    24.0    27.0    44.0

# %%
df.corr(numeric_only=True).round(3).style.background_gradient(axis=1).highlight_min(axis=1, color='pink' )
# Out:
# <style type="text/css">
# #T_62758_row0_col0, #T_62758_row1_col1, #T_62758_row2_col2, #T_62758_row3_col3, #T_62758_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_62758_row0_col1 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_62758_row0_col2, #T_62758_row2_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_62758_row0_col3, #T_62758_row1_col3, #T_62758_row2_col3, #T_62758_row3_col2, #T_62758_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: pink;
# }
# #T_62758_row0_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_62758_row1_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_62758_row1_col2 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_62758_row1_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_62758_row2_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_62758_row2_col4 {
#   background-color: #fbf4f9;
# ...

# %%
df.corr(numeric_only=True).round(3).style.background_gradient(axis=1, vmin =0.5).highlight_min(axis=1, color='pink')
# Out:
# <style type="text/css">
# #T_a97e3_row0_col0, #T_a97e3_row1_col1, #T_a97e3_row2_col2, #T_a97e3_row3_col3, #T_a97e3_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a97e3_row0_col1, #T_a97e3_row0_col4, #T_a97e3_row1_col0, #T_a97e3_row1_col2, #T_a97e3_row1_col4, #T_a97e3_row2_col1, #T_a97e3_row2_col4, #T_a97e3_row3_col0, #T_a97e3_row3_col1, #T_a97e3_row4_col1, #T_a97e3_row4_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a97e3_row0_col2, #T_a97e3_row2_col0 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_a97e3_row0_col3, #T_a97e3_row1_col3, #T_a97e3_row2_col3, #T_a97e3_row3_col2, #T_a97e3_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: pink;
# }
# #T_a97e3_row3_col4, #T_a97e3_row4_col3 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a97e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
df.corr(numeric_only=True).round(3).style.background_gradient(axis=1, vmin =0.5).highlight_min(axis=1, color='pink')
# Out:
# <style type="text/css">
# #T_81a36_row0_col0, #T_81a36_row1_col1, #T_81a36_row2_col2, #T_81a36_row3_col3, #T_81a36_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_81a36_row0_col1, #T_81a36_row0_col4, #T_81a36_row1_col0, #T_81a36_row1_col2, #T_81a36_row1_col4, #T_81a36_row2_col1, #T_81a36_row2_col4, #T_81a36_row3_col0, #T_81a36_row3_col1, #T_81a36_row4_col1, #T_81a36_row4_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_81a36_row0_col2, #T_81a36_row2_col0 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_81a36_row0_col3, #T_81a36_row1_col3, #T_81a36_row2_col3, #T_81a36_row3_col2, #T_81a36_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: pink;
# }
# #T_81a36_row3_col4, #T_81a36_row4_col3 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_81a36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
df.nlargest(5,columns='hwy')
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
# 196       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 105        honda       civic    1.8  2008    4    auto(l5)   f   25   36  r
#
#           class type
# 212     compact    m
# 221  subcompact    m
# 222  subcompact    a
# 196     compact    m
# 105  subcompact    a

# %%
df.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 6           audi                   a4    3.1  2008    6    auto(av)   f   18
# 67         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4   13
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 130   land rover          range rover    4.0  1999    8    auto(l4)   4   11
# 3           audi                   a4    2.0  2008    4    auto(av)   f   21
#
#      hwy fl    class type
# 6     27  p  compact    a
# 67    17  r   pickup    a
# 69    12  e   pickup    m
# 130   15  p      suv    a
# 3     30  p  compact    a

# %%
df[df.manufacturer.isin(['toyot','subaru'])].head(5)   # isin >>> need exact name
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 159       subaru  forester awd    2.5  1999    4  manual(m5)   4   18   25  r
# 160       subaru  forester awd    2.5  1999    4    auto(l4)   4   18   24  r
# 161       subaru  forester awd    2.5  2008    4  manual(m5)   4   20   27  r
# 162       subaru  forester awd    2.5  2008    4  manual(m5)   4   19   25  p
# 163       subaru  forester awd    2.5  2008    4    auto(l4)   4   20   26  r
#
#     class type
# 159   suv    m
# 160   suv    a
# 161   suv    m
# 162   suv    m
# 163   suv    a

# %% [markdown]
# another command use 'match' and used RegEx

# %%
df[df.manufacturer.str.contains('toyot|subaru', case=False)] # contain :  able to match some part
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 159       subaru            forester awd    2.5  1999    4  manual(m5)   4
# 160       subaru            forester awd    2.5  1999    4    auto(l4)   4
# 161       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 162       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 163       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 164       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 165       subaru             impreza awd    2.2  1999    4    auto(l4)   4
# 166       subaru             impreza awd    2.2  1999    4  manual(m5)   4
# 167       subaru             impreza awd    2.5  1999    4  manual(m5)   4
# 168       subaru             impreza awd    2.5  1999    4    auto(l4)   4
# 169       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# ...

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class', 'type'],
#       dtype='object')

# %%
df.drop([2])
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5           audi      a4    2.8  1999    6  manual(m5)   f   18   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class type
# 0    compact    a
# 1    compact    m
# 3    compact    a
# 4    compact    a
# ...

# %%
df.index[3:5]
# Out:
# RangeIndex(start=3, stop=5, step=1)

# %%
df.drop(df.index[3:5])
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 5           audi      a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6           audi      a4    3.1  2008    6    auto(av)   f   18   27  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class type
# 0    compact    a
# 1    compact    m
# 2    compact    m
# 5    compact    m
# ...

# %%
# df.manufacturer == 'audi'
df[df.manufacturer == 'audi']
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5          audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6          audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7          audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8          audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9          audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 10         audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# ...

# %%
# df.manufacturer == 'audi'
# df.manufacturer != 'audi'
df[df.manufacturer != 'audi']
# df[df.manufacturer == 'audi']
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 18     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 19     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 20     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 21     chevrolet  c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 22     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# ..           ...                 ...    ...   ...  ...         ...  ..  ...
# 229   volkswagen              passat    2.0  2008    4    auto(s6)   f   19
# 230   volkswagen              passat    2.0  2008    4  manual(m6)   f   21
# 231   volkswagen              passat    2.8  1999    6    auto(l5)   f   16
# 232   volkswagen              passat    2.8  1999    6  manual(m5)   f   18
# 233   volkswagen              passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class type
# 18    20  r      suv    a
# ...

# %%
df.drop(['manufacturer'],axis=1)
# Out:
#       model  displ  year  cyl       trans drv  cty  hwy fl    class type
# 0        a4    1.8  1999    4    auto(l5)   f   18   29  p  compact    a
# 1        a4    1.8  1999    4  manual(m5)   f   21   29  p  compact    m
# 2        a4    2.0  2008    4  manual(m6)   f   20   31  p  compact    m
# 3        a4    2.0  2008    4    auto(av)   f   21   30  p  compact    a
# 4        a4    2.8  1999    6    auto(l5)   f   16   26  p  compact    a
# ..      ...    ...   ...  ...         ...  ..  ...  ... ..      ...  ...
# 229  passat    2.0  2008    4    auto(s6)   f   19   28  p  midsize    a
# 230  passat    2.0  2008    4  manual(m6)   f   21   29  p  midsize    m
# 231  passat    2.8  1999    6    auto(l5)   f   16   26  p  midsize    a
# 232  passat    2.8  1999    6  manual(m5)   f   18   26  p  midsize    m
# 233  passat    3.6  2008    6    auto(s6)   f   17   26  p  midsize    a
#
# [234 rows x 11 columns]

# %%
df.drop(['manufacturer','year'],axis=1)
# Out:
#       model  displ  cyl       trans drv  cty  hwy fl    class type
# 0        a4    1.8    4    auto(l5)   f   18   29  p  compact    a
# 1        a4    1.8    4  manual(m5)   f   21   29  p  compact    m
# 2        a4    2.0    4  manual(m6)   f   20   31  p  compact    m
# 3        a4    2.0    4    auto(av)   f   21   30  p  compact    a
# 4        a4    2.8    6    auto(l5)   f   16   26  p  compact    a
# ..      ...    ...  ...         ...  ..  ...  ... ..      ...  ...
# 229  passat    2.0    4    auto(s6)   f   19   28  p  midsize    a
# 230  passat    2.0    4  manual(m6)   f   21   29  p  midsize    m
# 231  passat    2.8    6    auto(l5)   f   16   26  p  midsize    a
# 232  passat    2.8    6  manual(m5)   f   18   26  p  midsize    m
# 233  passat    3.6    6    auto(s6)   f   17   26  p  midsize    a
#
# [234 rows x 10 columns]

# %%
df.drop(['manufacturer','year'],axis=1, inplace=True)

# %%
df
# Out:
#       model  displ  cyl       trans drv  cty  hwy fl    class type
# 0        a4    1.8    4    auto(l5)   f   18   29  p  compact    a
# 1        a4    1.8    4  manual(m5)   f   21   29  p  compact    m
# 2        a4    2.0    4  manual(m6)   f   20   31  p  compact    m
# 3        a4    2.0    4    auto(av)   f   21   30  p  compact    a
# 4        a4    2.8    6    auto(l5)   f   16   26  p  compact    a
# ..      ...    ...  ...         ...  ..  ...  ... ..      ...  ...
# 229  passat    2.0    4    auto(s6)   f   19   28  p  midsize    a
# 230  passat    2.0    4  manual(m6)   f   21   29  p  midsize    m
# 231  passat    2.8    6    auto(l5)   f   16   26  p  midsize    a
# 232  passat    2.8    6  manual(m5)   f   18   26  p  midsize    m
# 233  passat    3.6    6    auto(s6)   f   17   26  p  midsize    a
#
# [234 rows x 10 columns]

# %%
df.rename(columns={'model':'Model','displ':'Displ'}, inplace= True)
df
# Out:
#     manufacturer   Model  Displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.columns = df.columns.str.lower()  #replace at level 'column' , left side need to be df.columns
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.columns
# Out:
# Index(['manufacturer', 'Model', 'Displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
df.columns.str.replace('Ma','ma')
# Out:
# Index(['manufacturer', 'Model', 'Displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace('C','c')
df.head(3)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact

# %%
df.columns = df.columns.str.lower().str.replace('h','Z')
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  Zwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.index.names
# Out:
# FrozenList([None])

# %%
df.sort_values('manufacturer',ascending =False)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 233   volkswagen      passat    3.6  2008    6    auto(s6)   f   17   26  p
# 220   volkswagen       jetta    2.8  1999    6  manual(m5)   f   17   24  r
# 207   volkswagen         gti    2.0  1999    4  manual(m5)   f   21   29  r
# 208   volkswagen         gti    2.0  1999    4    auto(l4)   f   19   26  r
# 209   volkswagen         gti    2.0  2008    4  manual(m6)   f   21   29  p
# ..           ...         ...    ...   ...  ...         ...  ..  ...  ... ..
# 14          audi  a4 quattro    3.1  2008    6  manual(m6)   4   15   25  p
# 15          audi  a6 quattro    2.8  1999    6    auto(l5)   4   15   24  p
# 16          audi  a6 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 17          audi  a6 quattro    4.2  2008    8    auto(s6)   4   16   23  p
# 0           audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
#
#        class
# 233  midsize
# 220  compact
# ...

# %%
df.sort_values(['manufacturer','model'],ascending =[True,False])
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 15          audi  a6 quattro    2.8  1999    6    auto(l5)   4   15   24  p
# 16          audi  a6 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 17          audi  a6 quattro    4.2  2008    8    auto(s6)   4   16   23  p
# 7           audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8           audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# ..           ...         ...    ...   ...  ...         ...  ..  ...  ... ..
# 207   volkswagen         gti    2.0  1999    4  manual(m5)   f   21   29  r
# 208   volkswagen         gti    2.0  1999    4    auto(l4)   f   19   26  r
# 209   volkswagen         gti    2.0  2008    4  manual(m6)   f   21   29  p
# 210   volkswagen         gti    2.0  2008    4    auto(s6)   f   22   29  p
# 211   volkswagen         gti    2.8  1999    6  manual(m5)   f   17   24  r
#
#        class
# 15   midsize
# 16   midsize
# ...

# %%
df.sort_values(['manufacturer','model'],ascending =[True,True])
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.sort_index(ascending=False)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
#
#        class
# 233  midsize
# 232  midsize
# 231  midsize
# 230  midsize
# 229  midsize
# ..       ...
# ...

# %%
df.sort_index(axis=1)
# Out:
#        class  cty  cyl  displ drv fl  hwy manufacturer   model       trans  \
# 0    compact   18    4    1.8   f  p   29         audi      a4    auto(l5)
# 1    compact   21    4    1.8   f  p   29         audi      a4  manual(m5)
# 2    compact   20    4    2.0   f  p   31         audi      a4  manual(m6)
# 3    compact   21    4    2.0   f  p   30         audi      a4    auto(av)
# 4    compact   16    6    2.8   f  p   26         audi      a4    auto(l5)
# ..       ...  ...  ...    ...  .. ..  ...          ...     ...         ...
# 229  midsize   19    4    2.0   f  p   28   volkswagen  passat    auto(s6)
# 230  midsize   21    4    2.0   f  p   29   volkswagen  passat  manual(m6)
# 231  midsize   16    6    2.8   f  p   26   volkswagen  passat    auto(l5)
# 232  midsize   18    6    2.8   f  p   26   volkswagen  passat  manual(m5)
# 233  midsize   17    6    3.6   f  p   26   volkswagen  passat    auto(s6)
#
#      year
# 0    1999
# 1    1999
# 2    2008
# 3    2008
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#      year       trans   model manufacturer  hwy fl drv  displ  cyl  cty  \
# 0    1999    auto(l5)      a4         audi   29  p   f    1.8    4   18
# 1    1999  manual(m5)      a4         audi   29  p   f    1.8    4   21
# 2    2008  manual(m6)      a4         audi   31  p   f    2.0    4   20
# 3    2008    auto(av)      a4         audi   30  p   f    2.0    4   21
# 4    1999    auto(l5)      a4         audi   26  p   f    2.8    6   16
# ..    ...         ...     ...          ...  ... ..  ..    ...  ...  ...
# 229  2008    auto(s6)  passat   volkswagen   28  p   f    2.0    4   19
# 230  2008  manual(m6)  passat   volkswagen   29  p   f    2.0    4   21
# 231  1999    auto(l5)  passat   volkswagen   26  p   f    2.8    6   16
# 232  1999  manual(m5)  passat   volkswagen   26  p   f    2.8    6   18
# 233  2008    auto(s6)  passat   volkswagen   26  p   f    3.6    6   17
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...
